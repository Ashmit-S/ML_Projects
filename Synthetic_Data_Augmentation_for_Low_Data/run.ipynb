# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Synthetic Data Augmentation
# Out:
# /content/drive/MyDrive/Synthetic Data Augmentation

# %%
# !pip install -r requirements.txt

# %%
# !python run_pipeline.py --skip_generate
# Out:
# Project root: /content/drive/MyDrive/Synthetic Data Augmentation
#
# ...
# Running: /usr/bin/python3 '/content/drive/MyDrive/Synthetic Data Augmentation/convert_yolo_to_classification.py' --yolo_root 'Helmet Detection.v5i.yolov8' --output_root data/classification/real
# ...
# Split 'train' -> 'train' done (class-folder mode). helmet=852, no_helmet=481, total=1333
# Split 'valid' -> 'val' done (class-folder mode). helmet=228, no_helmet=154, total=382
# Split 'test' -> 'test' done (class-folder mode). helmet=135, no_helmet=50, total=185
#
# All splits done.
# Output folder: data/classification/real
# Total images copied: helmet=1215, no_helmet=685, all=1900
# Skipping synthetic generation
#
# ...
# Running: /usr/bin/python3 '/content/drive/MyDrive/Synthetic Data Augmentation/train_classification.py' --real_root data/classification/real --epochs 3 --batch_size 16 --lr 0.001 --seed 42
# ...
# Model=resnet18 | num_real=20 | setup=real-only
# Subset folder: data/exp_cache/classification_subsets/n20_synth0_seed42
# ...
